# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import seaborn as sns

# %%
file_path = '../data/graphs.xlsx' 
df = pd.read_excel(file_path)

# %% [markdown]
# # Comparison of Actual, CCD, and ML Outputs

# %%
required_columns = ['actual', 'ccd', 'linear_regression']

plt.figure(figsize=(10, 6))
plt.plot(df.index, df['actual'], label='Actual', marker='o')
plt.plot(df.index, df['ccd'], label='CCD', marker='o')
plt.plot(df.index, df['linear_regression'], label='LR', marker='o')

plt.xlabel('Iteration (Row Index)')
plt.ylabel('Values')
plt.title('Comparison of Actual, CCD, and LR Outputs')
plt.legend()

plt.xticks(ticks=range(df.index.min(), df.index.max() + 1, 1))

plt.show()

# %% [markdown]
# # Scatter plot

# %%
scatter_matrix(df, figsize=(12, 12), diagonal='kde')
plt.show()

# %% [markdown]
# # Corelation map

# %%
corr = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.show()

# %% [markdown]
# # Pairwise Regression

# %%
sns.pairplot(df, kind='reg')
plt.show()
